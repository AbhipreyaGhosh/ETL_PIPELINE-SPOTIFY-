# %%
pip install spotipy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: spotipy in c:\users\abhipreya ghosh\appdata\roaming\python\python310\site-packages (2.22.1)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\abhipreya ghosh\appdata\roaming\python\python310\site-packages (from spotipy) (1.26.15)
# Requirement already satisfied: redis>=3.5.3 in c:\users\abhipreya ghosh\appdata\roaming\python\python310\site-packages (from spotipy) (4.5.3)
# Requirement already satisfied: six>=1.15.0 in c:\users\abhipreya ghosh\appdata\roaming\python\python310\site-packages (from spotipy) (1.16.0)
# Requirement already satisfied: requests>=2.25.0 in c:\users\abhipreya ghosh\appdata\roaming\python\python310\site-packages (from spotipy) (2.28.2)
# Requirement already satisfied: async-timeout>=4.0.2 in c:\users\abhipreya ghosh\appdata\roaming\python\python310\site-packages (from redis>=3.5.3->spotipy) (4.0.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\abhipreya ghosh\appdata\roaming\python\python310\site-packages (from requests>=2.25.0->spotipy) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\abhipreya ghosh\appdata\roaming\python\python310\site-packages (from requests>=2.25.0->spotipy) (3.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\abhipreya ghosh\appdata\roaming\python\python310\site-packages (from requests>=2.25.0->spotipy) (2022.12.7)
# Note: you may need to restart the kernel to use updated packages.

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
client_credentials_manager = SpotifyClientCredentials(client_id="7096a7392ca44852b08f36684444b55a", client_secret="2ffe7984069e438387820bc1a4be122c")

# %% [raw]
# sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link = "https://open.spotify.com/playlist/37i9dQZEVXbNG2KDcFcKOF"

# %%
playlist_URI = playlist_link.split("/")[4]

# %%
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
data = sp.playlist_tracks(playlist_URI)

# %%
data['items'][0]['track']['album']['id']
# Out:
# '0HiZ8fNXwJOQcrf5iflrdz'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'Endless Summer Vacation'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2023-03-10'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 13

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/0HiZ8fNXwJOQcrf5iflrdz'

# %%
album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_element = {'album_id':album_id,'name':album_name,'release_date':album_release_date,'total_tracks':album_total_tracks,'url':album_url}
    album_list.append(album_element)

# %%
album_list
# Out:
# [{'album_id': '0HiZ8fNXwJOQcrf5iflrdz',
#   'name': 'Endless Summer Vacation',
#   'release_date': '2023-03-10',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/0HiZ8fNXwJOQcrf5iflrdz'},
#  {'album_id': '4kS7bSuU0Jm9LYMosFU2x5',
#   'name': 'MAÑANA SERÁ BONITO',
#   'release_date': '2023-02-24',
#   'total_tracks': 17,
#   'url': 'https://open.spotify.com/album/4kS7bSuU0Jm9LYMosFU2x5'},
#  {'album_id': '1nrVofqDRs7cpWXJ49qTnP',
#   'name': 'SOS',
#   'release_date': '2022-12-08',
#   'total_tracks': 23,
#   'url': 'https://open.spotify.com/album/1nrVofqDRs7cpWXJ49qTnP'},
#  {'album_id': '6cVfHBcp3AdpYY0bBglkLN',
#   'name': "Boy's a liar Pt. 2",
#   'release_date': '2023-02-03',
#   'total_tracks': 2,
#   'url': 'https://open.spotify.com/album/6cVfHBcp3AdpYY0bBglkLN'},
#  {'album_id': '35dut3ICqF3NEDkjxfzJJ1',
#   'name': 'Starboy (Deluxe)',
#   'release_date': '2023-03-14',
#   'total_tracks': 21,
#   'url': 'https://open.spotify.com/album/35dut3ICqF3NEDkjxfzJJ1'},
#  {'album_id': '5r36AJ6VOJtp00oxSkBZ5h',
#   'name': "Harry's House",
#   'release_date': '2022-05-20',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/5r36AJ6VOJtp00oxSkBZ5h'},
#  {'album_id': '1gi2iwr1l8IUyHYHxi01pg',
#   'name': 'Shakira: Bzrp Music Sessions, Vol. 53',
#   'release_date': '2023-01-11',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1gi2iwr1l8IUyHYHxi01pg'},
#  {'album_id': '7txGsnDSqVMoRl6RQ9XyZP',
#   'name': 'HEROES & VILLAINS',
#   'release_date': '2022-12-02',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/7txGsnDSqVMoRl6RQ9XyZP'},
#  {'album_id': '5xefnzEqKIWnmTWYFzekGZ',
#   'name': 'Resistencia',
#   'release_date': '2023-01-13',
#   'total_tracks': 17,
#   'url': 'https://open.spotify.com/album/5xefnzEqKIWnmTWYFzekGZ'},
#  {'album_id': '3Mm1P5CEEAiuJqBclr2EyU',
#   'name': 'Ella Baila Sola',
#   'release_date': '2023-03-16',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3Mm1P5CEEAiuJqBclr2EyU'},
#  {'album_id': '2b2GHWESCWEuHiCZ2Skedp',
#   'name': 'Calm Down (with Selena Gomez)',
#   'release_date': '2022-08-25',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2b2GHWESCWEuHiCZ2Skedp'},
#  {'album_id': '1Uauz6ql2dIPvIOH4JiuhD',
#   'name': 'All Of The Girls You Loved Before',
#   'release_date': '2019-08-23',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1Uauz6ql2dIPvIOH4JiuhD'},
#  {'album_id': '151w1FgRZfnKZA9FEcg9Z3',
#   'name': 'Midnights',
#   'release_date': '2022-10-21',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/151w1FgRZfnKZA9FEcg9Z3'},
#  {'album_id': '781fDX4OibkZA9fj56Ycbz',
#   'name': 'Set Me Free Pt.2',
#   'release_date': '2023-03-17',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/781fDX4OibkZA9fj56Ycbz'},
#  {'album_id': '3Uq1jNGnD412ZvCb6j2DKV',
#   'name': 'Gloria',
#   'release_date': '2023-01-27',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/3Uq1jNGnD412ZvCb6j2DKV'},
#  {'album_id': '4AdZV63ycxFLF6Hcol0QnB',
#   'name': 'Starboy',
#   'release_date': '2016-11-24',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/4AdZV63ycxFLF6Hcol0QnB'},
#  {'album_id': '7M842DMhYVALrXsw3ty7B3',
#   'name': "I'm Good (Blue)",
#   'release_date': '2022-08-26',
#   'total_tracks': 2,
#   'url': 'https://open.spotify.com/album/7M842DMhYVALrXsw3ty7B3'},
#  {'album_id': '7ubO2LZJZFpyhiWMZkRwcH',
#   'name': '2000',
#   'release_date': '2023-03-17',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/7ubO2LZJZFpyhiWMZkRwcH'},
#  {'album_id': '4eoF8b15EaosNzpn2N3Rt9',
#   'name': 'Shorty Party',
#   'release_date': '2023-03-04',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/4eoF8b15EaosNzpn2N3Rt9'},
#  {'album_id': '0OuoHWf8yB0TPzoBWw1R1S',
#   'name': 'Here With Me',
#   'release_date': '2022-09-22',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/0OuoHWf8yB0TPzoBWw1R1S'},
#  {'album_id': '1kjfMVBNhsDeRyAu9zbLfF',
#   'name': 'OzuTochi',
#   'release_date': '2022-10-07',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/1kjfMVBNhsDeRyAu9zbLfF'},
#  {'album_id': '7ARtQpvnPN2ucbmVHngLOs',
#   'name': 'Until I Found You (Em Beihold Version)',
#   'release_date': '2022-04-22',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/7ARtQpvnPN2ucbmVHngLOs'},
#  {'album_id': '6i7mF7whyRJuLJ4ogbH2wh',
#   'name': 'One Thing At A Time',
#   'release_date': '2023-03-03',
#   'total_tracks': 36,
#   'url': 'https://open.spotify.com/album/6i7mF7whyRJuLJ4ogbH2wh'},
#  {'album_id': '2OXBosbXT7Qs3J6vBd6IkI',
#   'name': 'PRC',
#   'release_date': '2023-01-23',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2OXBosbXT7Qs3J6vBd6IkI'},
#  {'album_id': '0s2sLResjP92wRavoj9k0O',
#   'name': 'AMG',
#   'release_date': '2022-11-24',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/0s2sLResjP92wRavoj9k0O'},
#  {'album_id': '3U8n8LzBx2o9gYXvvNq4uH',
#   'name': 'My 21st Century Blues',
#   'release_date': '2023-02-03',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/3U8n8LzBx2o9gYXvvNq4uH'},
#  {'album_id': '45ozep8uHHnj5CCittuyXj',
#   'name': "NewJeans 'OMG'",
#   'release_date': '2023-01-02',
#   'total_tracks': 2,
#   'url': 'https://open.spotify.com/album/45ozep8uHHnj5CCittuyXj'},
#  {'album_id': '6BGN5CVd7koJApotl5Bj8u',
#   'name': '3MEN2 KBRN',
#   'release_date': '2023-03-17',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/6BGN5CVd7koJApotl5Bj8u'},
#  {'album_id': '2ODvWsOgouMbaA5xf0RkJe',
#   'name': 'Starboy',
#   'release_date': '2016-11-25',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/2ODvWsOgouMbaA5xf0RkJe'},
#  {'album_id': '4cAAsw7mPkGt15GXQzWlrM',
#   'name': 'Players',
#   'release_date': '2022-11-30',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/4cAAsw7mPkGt15GXQzWlrM'},
#  {'album_id': '4PNqWiJAfjj32hVvlchV5u',
#   'name': 'Quevedo: Bzrp Music Sessions, Vol. 52',
#   'release_date': '2022-07-06',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/4PNqWiJAfjj32hVvlchV5u'},
#  {'album_id': '0KGBW1MQtC2aFPCDUdAkdJ',
#   'name': 'Long Way Down',
#   'release_date': '2013-06-17',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/0KGBW1MQtC2aFPCDUdAkdJ'},
#  {'album_id': '78bpIziExqiI9qztvNFlQu',
#   'name': 'AM',
#   'release_date': '2013-09-09',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/78bpIziExqiI9qztvNFlQu'},
#  {'album_id': '69AaAkdktFGnk9POmHENkT',
#   'name': 'this is what ____ feels like (Vol. 1-4)',
#   'release_date': '2022-09-23',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/69AaAkdktFGnk9POmHENkT'},
#  {'album_id': '68L5xVV9wydotfDXEik7eD',
#   'name': 'five seconds flat',
#   'release_date': '2022-04-08',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/68L5xVV9wydotfDXEik7eD'},
#  {'album_id': '33inEak0hNKMDePhjGxE61',
#   'name': 'OneRepublic (Japan Paradise Tour Edition)',
#   'release_date': '2023-02-15',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/33inEak0hNKMDePhjGxE61'},
#  {'album_id': '2AvuFDqTlnxvYhyVaLU6NY',
#   'name': 'Sr. Santos',
#   'release_date': '2022-12-01',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/2AvuFDqTlnxvYhyVaLU6NY'},
#  {'album_id': '7pijRxgRaBirPz6wDaJIp9',
#   'name': 'FELIZ CUMPLEAÑOS FERXXO TE PIRATEAMOS EL ÁLBUM',
#   'release_date': '2022-09-14',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/7pijRxgRaBirPz6wDaJIp9'},
#  {'album_id': '07w0rG5TETcyihsEIZR3qG',
#   'name': 'SOS',
#   'release_date': '2022-12-09',
#   'total_tracks': 23,
#   'url': 'https://open.spotify.com/album/07w0rG5TETcyihsEIZR3qG'},
#  {'album_id': '26wRfIX4WqKLKHll9O3KnF',
#   'name': 'Rara Vez',
#   'release_date': '2023-02-08',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/26wRfIX4WqKLKHll9O3KnF'},
#  {'album_id': '493HYe7N5pleudEZRyhE7R',
#   'name': 'All I Want Is You',
#   'release_date': '2010-11-26',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/493HYe7N5pleudEZRyhE7R'},
#  {'album_id': '4kS7bSuU0Jm9LYMosFU2x5',
#   'name': 'MAÑANA SERÁ BONITO',
#   'release_date': '2023-02-24',
#   'total_tracks': 17,
#   'url': 'https://open.spotify.com/album/4kS7bSuU0Jm9LYMosFU2x5'},
#  {'album_id': '6yiXkzHvC0OTmhfDQOEWtS',
#   'name': 'Mercury - Acts 1 & 2',
#   'release_date': '2022-07-01',
#   'total_tracks': 32,
#   'url': 'https://open.spotify.com/album/6yiXkzHvC0OTmhfDQOEWtS'},
#  {'album_id': '4wtZQMNTC1O79kDxMBsEan',
#   'name': 'Cracker Island',
#   'release_date': '2023-02-24',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/4wtZQMNTC1O79kDxMBsEan'},
#  {'album_id': '366AAoKCXunrJSqKqZuafy',
#   'name': 'Fin de Semana',
#   'release_date': '2023-01-13',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/366AAoKCXunrJSqKqZuafy'},
#  {'album_id': '31L7J7AO993tSBxAunoeoa',
#   'name': 'SIXDO',
#   'release_date': '2022-12-02',
#   'total_tracks': 6,
#   'url': 'https://open.spotify.com/album/31L7J7AO993tSBxAunoeoa'},
#  {'album_id': '4kS7bSuU0Jm9LYMosFU2x5',
#   'name': 'MAÑANA SERÁ BONITO',
#   'release_date': '2023-02-24',
#   'total_tracks': 17,
#   'url': 'https://open.spotify.com/album/4kS7bSuU0Jm9LYMosFU2x5'},
#  {'album_id': '1kTlYbs28MXw7hwO0NLYif',
#   'name': 'Encore (Deluxe Version)',
#   'release_date': '2004-11-12',
#   'total_tracks': 23,
#   'url': 'https://open.spotify.com/album/1kTlYbs28MXw7hwO0NLYif'},
#  {'album_id': '5beJZJo0DqVaPVlA1cHwjj',
#   'name': 'MERCHO',
#   'release_date': '2022-12-16',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5beJZJo0DqVaPVlA1cHwjj'},
#  {'album_id': '2FD6g8bXEn2uQMYbeqqoCg',
#   'name': 'Just Wanna Rock',
#   'release_date': '2022-10-17',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2FD6g8bXEn2uQMYbeqqoCg'}]

# %%
artist_list = []
for row in data['items']:
    for key, value in row.items():
        if key == "track":
            for artist in value['artists']:
                artist_dict = {'artist_id':artist['id'],'artist_name':artist['name'],'external_url':artist['href']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '5YGY8feqx7naU7z4HrwZM6',
#   'artist_name': 'Miley Cyrus',
#   'external_url': 'https://api.spotify.com/v1/artists/5YGY8feqx7naU7z4HrwZM6'},
#  {'artist_id': '790FomKkXshlbRYZFtlgla',
#   'artist_name': 'KAROL G',
#   'external_url': 'https://api.spotify.com/v1/artists/790FomKkXshlbRYZFtlgla'},
#  {'artist_id': '0EmeFodog0BfCgMzAIvKQp',
#   'artist_name': 'Shakira',
#   'external_url': 'https://api.spotify.com/v1/artists/0EmeFodog0BfCgMzAIvKQp'},
#  {'artist_id': '7tYKF4w9nC0nq9CsPZTHyP',
#   'artist_name': 'SZA',
#   'external_url': 'https://api.spotify.com/v1/artists/7tYKF4w9nC0nq9CsPZTHyP'},
#  {'artist_id': '78rUTD7y6Cy67W1RVzYs7t',
#   'artist_name': 'PinkPantheress',
#   'external_url': 'https://api.spotify.com/v1/artists/78rUTD7y6Cy67W1RVzYs7t'},
#  {'artist_id': '3LZZPxNDGDFVSIPqf4JuEf',
#   'artist_name': 'Ice Spice',
#   'external_url': 'https://api.spotify.com/v1/artists/3LZZPxNDGDFVSIPqf4JuEf'},
#  {'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ',
#   'artist_name': 'The Weeknd',
#   'external_url': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'artist_id': '66CXWjxzNUsdJxJ2JdwvnR',
#   'artist_name': 'Ariana Grande',
#   'external_url': 'https://api.spotify.com/v1/artists/66CXWjxzNUsdJxJ2JdwvnR'},
#  {'artist_id': '6KImCVD70vtIoJWnq6nGn3',
#   'artist_name': 'Harry Styles',
#   'external_url': 'https://api.spotify.com/v1/artists/6KImCVD70vtIoJWnq6nGn3'},
#  {'artist_id': '716NhGYqD1jl2wI1Qkgq36',
#   'artist_name': 'Bizarrap',
#   'external_url': 'https://api.spotify.com/v1/artists/716NhGYqD1jl2wI1Qkgq36'},
#  {'artist_id': '0EmeFodog0BfCgMzAIvKQp',
#   'artist_name': 'Shakira',
#   'external_url': 'https://api.spotify.com/v1/artists/0EmeFodog0BfCgMzAIvKQp'},
#  {'artist_id': '0iEtIxbK0KxaSlF7G42ZOp',
#   'artist_name': 'Metro Boomin',
#   'external_url': 'https://api.spotify.com/v1/artists/0iEtIxbK0KxaSlF7G42ZOp'},
#  {'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ',
#   'artist_name': 'The Weeknd',
#   'external_url': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'artist_id': '1URnnhqYAYcrqrcwql10ft',
#   'artist_name': '21 Savage',
#   'external_url': 'https://api.spotify.com/v1/artists/1URnnhqYAYcrqrcwql10ft'},
#  {'artist_id': '0eHQ9o50hj6ZDNBt6Ys1sD',
#   'artist_name': 'Yandel',
#   'external_url': 'https://api.spotify.com/v1/artists/0eHQ9o50hj6ZDNBt6Ys1sD'},
#  {'artist_id': '2LRoIwlKmHjgvigdNGBHNo',
#   'artist_name': 'Feid',
#   'external_url': 'https://api.spotify.com/v1/artists/2LRoIwlKmHjgvigdNGBHNo'},
#  {'artist_id': '0XeEobZplHxzM9QzFQWLiR',
#   'artist_name': 'Eslabon Armado',
#   'external_url': 'https://api.spotify.com/v1/artists/0XeEobZplHxzM9QzFQWLiR'},
#  {'artist_id': '12GqGscKJx3aE4t07u7eVZ',
#   'artist_name': 'Peso Pluma',
#   'external_url': 'https://api.spotify.com/v1/artists/12GqGscKJx3aE4t07u7eVZ'},
#  {'artist_id': '46pWGuE3dSwY3bMMXGBvVS',
#   'artist_name': 'Rema',
#   'external_url': 'https://api.spotify.com/v1/artists/46pWGuE3dSwY3bMMXGBvVS'},
#  {'artist_id': '0C8ZW7ezQVs4URX5aX7Kqx',
#   'artist_name': 'Selena Gomez',
#   'external_url': 'https://api.spotify.com/v1/artists/0C8ZW7ezQVs4URX5aX7Kqx'},
#  {'artist_id': '06HL4z0CvFAxyc27GXpf02',
#   'artist_name': 'Taylor Swift',
#   'external_url': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02'},
#  {'artist_id': '06HL4z0CvFAxyc27GXpf02',
#   'artist_name': 'Taylor Swift',
#   'external_url': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02'},
#  {'artist_id': '1oSPZhvZMIrWW5I41kPkkY',
#   'artist_name': 'Jimin',
#   'external_url': 'https://api.spotify.com/v1/artists/1oSPZhvZMIrWW5I41kPkkY'},
#  {'artist_id': '2wY79sveU1sp5g7SokKOiI',
#   'artist_name': 'Sam Smith',
#   'external_url': 'https://api.spotify.com/v1/artists/2wY79sveU1sp5g7SokKOiI'},
#  {'artist_id': '3Xt3RrJMFv5SZkCfUE8C1J',
#   'artist_name': 'Kim Petras',
#   'external_url': 'https://api.spotify.com/v1/artists/3Xt3RrJMFv5SZkCfUE8C1J'},
#  {'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ',
#   'artist_name': 'The Weeknd',
#   'external_url': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'artist_id': '1Cs0zKBU1kc0i8ypK3B9ai',
#   'artist_name': 'David Guetta',
#   'external_url': 'https://api.spotify.com/v1/artists/1Cs0zKBU1kc0i8ypK3B9ai'},
#  {'artist_id': '64M6ah0SkkRsnPGtGiRAbb',
#   'artist_name': 'Bebe Rexha',
#   'external_url': 'https://api.spotify.com/v1/artists/64M6ah0SkkRsnPGtGiRAbb'},
#  {'artist_id': '0tmwSHipWxN12fsoLcFU3B',
#   'artist_name': 'Manuel Turizo',
#   'external_url': 'https://api.spotify.com/v1/artists/0tmwSHipWxN12fsoLcFU3B'},
#  {'artist_id': '07PdYoE4jVRF6Ut40GgVSP',
#   'artist_name': 'Cartel De Santa',
#   'external_url': 'https://api.spotify.com/v1/artists/07PdYoE4jVRF6Ut40GgVSP'},
#  {'artist_id': '4yEIQ0lJDgUEfsuYx3Gsmr',
#   'artist_name': 'La Kelly',
#   'external_url': 'https://api.spotify.com/v1/artists/4yEIQ0lJDgUEfsuYx3Gsmr'},
#  {'artist_id': '5y8tKLUfMvliMe8IKamR32',
#   'artist_name': 'd4vd',
#   'external_url': 'https://api.spotify.com/v1/artists/5y8tKLUfMvliMe8IKamR32'},
#  {'artist_id': '1i8SpTcr7yvPOmcqrbnVXY',
#   'artist_name': 'Ozuna',
#   'external_url': 'https://api.spotify.com/v1/artists/1i8SpTcr7yvPOmcqrbnVXY'},
#  {'artist_id': '2LRoIwlKmHjgvigdNGBHNo',
#   'artist_name': 'Feid',
#   'external_url': 'https://api.spotify.com/v1/artists/2LRoIwlKmHjgvigdNGBHNo'},
#  {'artist_id': '5XKFrudbV4IiuE5WuTPRmT',
#   'artist_name': 'Stephen Sanchez',
#   'external_url': 'https://api.spotify.com/v1/artists/5XKFrudbV4IiuE5WuTPRmT'},
#  {'artist_id': '7o2ZQYM7nTsaVdkXY38UAA',
#   'artist_name': 'Em Beihold',
#   'external_url': 'https://api.spotify.com/v1/artists/7o2ZQYM7nTsaVdkXY38UAA'},
#  {'artist_id': '4oUHIQIBe0LHzYfvXNW4QM',
#   'artist_name': 'Morgan Wallen',
#   'external_url': 'https://api.spotify.com/v1/artists/4oUHIQIBe0LHzYfvXNW4QM'},
#  {'artist_id': '12GqGscKJx3aE4t07u7eVZ',
#   'artist_name': 'Peso Pluma',
#   'external_url': 'https://api.spotify.com/v1/artists/12GqGscKJx3aE4t07u7eVZ'},
#  {'artist_id': '0elWFr7TW8piilVRYJUe4P',
#   'artist_name': 'Natanael Cano',
#   'external_url': 'https://api.spotify.com/v1/artists/0elWFr7TW8piilVRYJUe4P'},
#  {'artist_id': '0elWFr7TW8piilVRYJUe4P',
#   'artist_name': 'Natanael Cano',
#   'external_url': 'https://api.spotify.com/v1/artists/0elWFr7TW8piilVRYJUe4P'},
#  {'artist_id': '12GqGscKJx3aE4t07u7eVZ',
#   'artist_name': 'Peso Pluma',
#   'external_url': 'https://api.spotify.com/v1/artists/12GqGscKJx3aE4t07u7eVZ'},
#  {'artist_id': '6Sbl0NT50roqWvy746MfVf',
#   'artist_name': 'Gabito Ballesteros',
#   'external_url': 'https://api.spotify.com/v1/artists/6Sbl0NT50roqWvy746MfVf'},
#  {'artist_id': '5KKpBU5eC2tJDzf0wmlRp2',
#   'artist_name': 'RAYE',
#   'external_url': 'https://api.spotify.com/v1/artists/5KKpBU5eC2tJDzf0wmlRp2'},
#  {'artist_id': '12Zk1DFhCbHY6v3xep2ZjI',
#   'artist_name': '070 Shake',
#   'external_url': 'https://api.spotify.com/v1/artists/12Zk1DFhCbHY6v3xep2ZjI'},
#  {'artist_id': '6HvZYsbFfjnjFrWF950C9d',
#   'artist_name': 'NewJeans',
#   'external_url': 'https://api.spotify.com/v1/artists/6HvZYsbFfjnjFrWF950C9d'},
#  {'artist_id': '5XJDexmWFLWOkjOEjOVX3e',
#   'artist_name': 'Eladio Carrion',
#   'external_url': 'https://api.spotify.com/v1/artists/5XJDexmWFLWOkjOEjOVX3e'},
#  {'artist_id': '4q3ewBCX7sLwd24euuV69X',
#   'artist_name': 'Bad Bunny',
#   'external_url': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X'},
#  {'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ',
#   'artist_name': 'The Weeknd',
#   'external_url': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'artist_id': '4tZwfgrHOc3mvqYlEYSvVi',
#   'artist_name': 'Daft Punk',
#   'external_url': 'https://api.spotify.com/v1/artists/4tZwfgrHOc3mvqYlEYSvVi'},
#  {'artist_id': '6AMd49uBDJfhf30Ak2QR5s',
#   'artist_name': 'Coi Leray',
#   'external_url': 'https://api.spotify.com/v1/artists/6AMd49uBDJfhf30Ak2QR5s'},
#  {'artist_id': '716NhGYqD1jl2wI1Qkgq36',
#   'artist_name': 'Bizarrap',
#   'external_url': 'https://api.spotify.com/v1/artists/716NhGYqD1jl2wI1Qkgq36'},
#  {'artist_id': '52iwsT98xCoGgiGntTiR7K',
#   'artist_name': 'Quevedo',
#   'external_url': 'https://api.spotify.com/v1/artists/52iwsT98xCoGgiGntTiR7K'},
#  {'artist_id': '2txHhyCwHjUEpJjWrEyqyX',
#   'artist_name': 'Tom Odell',
#   'external_url': 'https://api.spotify.com/v1/artists/2txHhyCwHjUEpJjWrEyqyX'},
#  {'artist_id': '7Ln80lUS6He07XvHI8qqHH',
#   'artist_name': 'Arctic Monkeys',
#   'external_url': 'https://api.spotify.com/v1/artists/7Ln80lUS6He07XvHI8qqHH'},
#  {'artist_id': '164Uj4eKjl6zTBKfJLFKKK',
#   'artist_name': 'JVKE',
#   'external_url': 'https://api.spotify.com/v1/artists/164Uj4eKjl6zTBKfJLFKKK'},
#  {'artist_id': '1GmsPCcpKgF9OhlNXjOsbS',
#   'artist_name': 'Lizzy McAlpine',
#   'external_url': 'https://api.spotify.com/v1/artists/1GmsPCcpKgF9OhlNXjOsbS'},
#  {'artist_id': '5Pwc4xIPtQLFEnJriah9YJ',
#   'artist_name': 'OneRepublic',
#   'external_url': 'https://api.spotify.com/v1/artists/5Pwc4xIPtQLFEnJriah9YJ'},
#  {'artist_id': '4SsVbpTthjScTS7U2hmr1X',
#   'artist_name': 'Arcángel',
#   'external_url': 'https://api.spotify.com/v1/artists/4SsVbpTthjScTS7U2hmr1X'},
#  {'artist_id': '4q3ewBCX7sLwd24euuV69X',
#   'artist_name': 'Bad Bunny',
#   'external_url': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X'},
#  {'artist_id': '2LRoIwlKmHjgvigdNGBHNo',
#   'artist_name': 'Feid',
#   'external_url': 'https://api.spotify.com/v1/artists/2LRoIwlKmHjgvigdNGBHNo'},
#  {'artist_id': '7tYKF4w9nC0nq9CsPZTHyP',
#   'artist_name': 'SZA',
#   'external_url': 'https://api.spotify.com/v1/artists/7tYKF4w9nC0nq9CsPZTHyP'},
#  {'artist_id': '5szJHKg5xeUlQ9pTqzdpic',
#   'artist_name': 'Taiu',
#   'external_url': 'https://api.spotify.com/v1/artists/5szJHKg5xeUlQ9pTqzdpic'},
#  {'artist_id': '19HM5j0ULGSmEoRcrSe5x3',
#   'artist_name': 'Milo j',
#   'external_url': 'https://api.spotify.com/v1/artists/19HM5j0ULGSmEoRcrSe5x3'},
#  {'artist_id': '360IAlyVv4PCEVjgyMZrxK',
#   'artist_name': 'Miguel',
#   'external_url': 'https://api.spotify.com/v1/artists/360IAlyVv4PCEVjgyMZrxK'},
#  {'artist_id': '790FomKkXshlbRYZFtlgla',
#   'artist_name': 'KAROL G',
#   'external_url': 'https://api.spotify.com/v1/artists/790FomKkXshlbRYZFtlgla'},
#  {'artist_id': '53XhwfbYqKCa1cC15pYq2q',
#   'artist_name': 'Imagine Dragons',
#   'external_url': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q'},
#  {'artist_id': '3AA28KZvwAUcZuOKwyblJQ',
#   'artist_name': 'Gorillaz',
#   'external_url': 'https://api.spotify.com/v1/artists/3AA28KZvwAUcZuOKwyblJQ'},
#  {'artist_id': '4q3ewBCX7sLwd24euuV69X',
#   'artist_name': 'Bad Bunny',
#   'external_url': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X'},
#  {'artist_id': '3l9G1G9MxH6DaRhwLklaf5',
#   'artist_name': 'Oscar Maydon',
#   'external_url': 'https://api.spotify.com/v1/artists/3l9G1G9MxH6DaRhwLklaf5'},
#  {'artist_id': '7Gi6gjaWy3DxyilpF1a8Is',
#   'artist_name': 'Junior H',
#   'external_url': 'https://api.spotify.com/v1/artists/7Gi6gjaWy3DxyilpF1a8Is'},
#  {'artist_id': '2LRoIwlKmHjgvigdNGBHNo',
#   'artist_name': 'Feid',
#   'external_url': 'https://api.spotify.com/v1/artists/2LRoIwlKmHjgvigdNGBHNo'},
#  {'artist_id': '790FomKkXshlbRYZFtlgla',
#   'artist_name': 'KAROL G',
#   'external_url': 'https://api.spotify.com/v1/artists/790FomKkXshlbRYZFtlgla'},
#  {'artist_id': '5lwmRuXgjX8xIwlnauTZIP',
#   'artist_name': 'Romeo Santos',
#   'external_url': 'https://api.spotify.com/v1/artists/5lwmRuXgjX8xIwlnauTZIP'},
#  {'artist_id': '7dGJo4pcD2V6oG8kP0tJRR',
#   'artist_name': 'Eminem',
#   'external_url': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR'},
#  {'artist_id': '0niAkxgT6y57bRbT0Ge94z',
#   'artist_name': 'LiL CaKe',
#   'external_url': 'https://api.spotify.com/v1/artists/0niAkxgT6y57bRbT0Ge94z'},
#  {'artist_id': '48R2gYdPKtfnfKAzhSVPUx',
#   'artist_name': 'Migrantes',
#   'external_url': 'https://api.spotify.com/v1/artists/48R2gYdPKtfnfKAzhSVPUx'},
#  {'artist_id': '0uxYECT7XqHNccQAg5Uhe4',
#   'artist_name': 'Nico Valdi',
#   'external_url': 'https://api.spotify.com/v1/artists/0uxYECT7XqHNccQAg5Uhe4'},
#  {'artist_id': '4O15NlyKLIASxsJ0PrXPfz',
#   'artist_name': 'Lil Uzi Vert',
#   'external_url': 'https://api.spotify.com/v1/artists/4O15NlyKLIASxsJ0PrXPfz'}]

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id,'song_name':song_name,'duration_ms':song_duration,'url':song_url,
                    'popularity':song_popularity,'song_added':song_added,'album_id':album_id, 'artist_id':artist_id
                   }
    song_list.append(song_element)

# %%
album_df = pd.DataFrame.from_dict(album_list)

# %%
album_df.head()
# Out:
#                  album_id                     name release_date  total_tracks  \
# 0  0HiZ8fNXwJOQcrf5iflrdz  Endless Summer Vacation   2023-03-10            13
# 1  4kS7bSuU0Jm9LYMosFU2x5       MAÑANA SERÁ BONITO   2023-02-24            17
# 2  1nrVofqDRs7cpWXJ49qTnP                      SOS   2022-12-08            23
# 3  6cVfHBcp3AdpYY0bBglkLN       Boy's a liar Pt. 2   2023-02-03             2
# 4  35dut3ICqF3NEDkjxfzJJ1         Starboy (Deluxe)   2023-03-14            21
#
#                                                  url
# 0  https://open.spotify.com/album/0HiZ8fNXwJOQcrf...
# 1  https://open.spotify.com/album/4kS7bSuU0Jm9LYM...
# 2  https://open.spotify.com/album/1nrVofqDRs7cpWX...
# 3  https://open.spotify.com/album/6cVfHBcp3AdpYY0...
# 4  https://open.spotify.com/album/35dut3ICqF3NEDk...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      50 non-null     object
#  1   name          50 non-null     object
#  2   release_date  50 non-null     object
#  3   total_tracks  50 non-null     int64
#  4   url           50 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.1+ KB

# %%
#remove duplicates from primary key because of 1 to many relationship
album_df = album_df.drop_duplicates(subset=['album_id'])

# %%
#get artist info
artist_df = pd.DataFrame.from_dict(artist_list)

# %%
artist_df = artist_df.drop_duplicates(subset=['artist_id'])

# %%
#song dataframe and no need to delete duplicates due to unique names 
song_df = pd.DataFrame.from_dict(song_list)

# %%
song_df
# Out:
#                    song_id                                          song_name  \
# 0   4DHcnVTT87F0zZhRPYmZ3B                                            Flowers
# 1   0DWdj2oZMBFSzRsi2Cvfzf                                                TQG
# 2   1Qrg8KqiBpW07V7PNxwwwL                                          Kill Bill
# 3   6AQbmUe0Qwf5PZnt4HmTXv                                 Boy's a liar Pt. 2
# 4   4W4fNrZYkobj539TOWsLO2           Die For You (with Ariana Grande) - Remix
# 5   4Dvkj6JhhA12EX05fT7y2e                                          As It Was
# 6   4nrPB8O7Y7wsOCJdgXkthe              Shakira: Bzrp Music Sessions, Vol. 53
# 7   2dHHgzDwk4BJdRwy9uXhTO             Creepin' (with The Weeknd & 21 Savage)
# 8   4FAKtPVycI4DxoOHC01YqD                                         Yandel 150
# 9   3dnP0JxCgygwQH9Gm7q7nb                                    Ella Baila Sola
# 10  0WtM2NBVQNNJLh6scP13H8                      Calm Down (with Selena Gomez)
# 11  4P9Q0GojKVXpRTJCaL3kyy                  All Of The Girls You Loved Before
# 12  0V3wPSX9ygBnCm8psDIegu                                          Anti-Hero
# 13  59hBR0BCtJsfIbV9VzCVAp                                   Set Me Free Pt.2
# 14  0NZPBYD5qbEWRs3PrGiRkT                          Unholy (feat. Kim Petras)
# 15  2LBqCSwhJGcFQeTHMVGwy3                                        Die For You
# 16  4uUG5RXrOk84mYEfFvj3cK                                    I'm Good (Blue)
# 17  3tt9i3Hhzq84dPS8H7iSiJ                                         La Bachata
# 18  55ZATsjPlTeSTNJOuW90pW                                       Shorty Party
# 19  78Sw5GDo6AlGwTwanjXbGh                                       Here With Me
# 20  1zsPaEkglFvxjAhrM8yhpr                                            Hey Mor
# 21  1Y3LN4zO1Edc2EluIoSPJN  Until I Found You (with Em Beihold) - Em Beiho...
# 22  7K3BhSpAxZBznislvUMVtn                                         Last Night
# 23  2mpoNBkngUEwnaKoBhZ0vl                                                PRC
# 24  1lRtH4FszTrwwlK5gTSbXO                                                AMG
# 25  5mHdCZtVyb4DcJw8799hZp                                          Escapism.
# 26  65FftemJ1DbbZ45DUfHJXE                                                OMG
# 27  0PB0O24JqAuNdOAFVJljMS                                        Coco Chanel
# 28  7MXVkk9YMctZqd1Srtv4MB                                            Starboy
# 29  6UN73IYd0hZxLi8wFPMQij                                            Players
# 30  2tTmW7RDtMQtBk7m2rYeSw              Quevedo: Bzrp Music Sessions, Vol. 52
# 31  7jtQIBanIiJOMS6RyCx6jZ                                       Another Love
# 32  5XeFesFbtLpXzIVDNQP22n                                   I Wanna Be Yours
# 33  5odlY52u43F5BjByhxg7wg                                        golden hour
# 34  2L9N0zZnd37dwF0clgxMGI                                           ceilings
# 35  4fYte8ZvTK14NEhAOZocBi                                    I Ain't Worried
# 36  2mnXxnrX5vCGolNkaFvVeM                                           La Jumpa
# 37  2CeKVsFFXG4QzA415QygGb                            Feliz Cumpleaños Ferxxo
# 38  4iZ4pt7kvcaH6Yo8UoZ4s2                                             Snooze
# 39  7MVIfkyzuUmQ716j8U7yGR                                           Rara Vez
# 40  0JXXNGljqupsJaZsgSbMZV                                         Sure Thing
# 41  6otePxalBK8AVa20xhZYVQ                          MIENTRAS ME CURO DEL CORA
# 42  54ipXppHLA8U4yqpOFTUhr                                              Bones
# 43  38UYeBLfvpnDSG9GznZdnL                         Tormenta (feat. Bad Bunny)
# 44  6TBzRwnX2oYd8aOrOuyK1p                                      Fin de Semana
# 45  0CYTGMBYkwUxrj1MWDLrC5                             CHORRITO PA LAS ANIMAS
# 46  4NoOME4Dhf4xgxbHDT7VGe                                      X SI VOLVEMOS
# 47  561jH07mF1jHuk7KlaeF0s                                        Mockingbird
# 48  1DxEbt6OSbrkRthk6pjZue                                             MERCHO
# 49  4FyesJzVpA39hbYvcseO2d                                    Just Wanna Rock
#
#     duration_ms                                                url  \
# 0        200600  https://open.spotify.com/track/4DHcnVTT87F0zZh...
# 1        197933  https://open.spotify.com/track/0DWdj2oZMBFSzRs...
# 2        153946  https://open.spotify.com/track/1Qrg8KqiBpW07V7...
# 3        131013  https://open.spotify.com/track/6AQbmUe0Qwf5PZn...
# 4        232857  https://open.spotify.com/track/4W4fNrZYkobj539...
# 5        167303  https://open.spotify.com/track/4Dvkj6JhhA12EX0...
# 6        214945  https://open.spotify.com/track/4nrPB8O7Y7wsOCJ...
# 7        221520  https://open.spotify.com/track/2dHHgzDwk4BJdRw...
# 8        216148  https://open.spotify.com/track/4FAKtPVycI4DxoO...
# 9        165671  https://open.spotify.com/track/3dnP0JxCgygwQH9...
# 10       239317  https://open.spotify.com/track/0WtM2NBVQNNJLh6...
# 11       221407  https://open.spotify.com/track/4P9Q0GojKVXpRTJ...
# 12       200690  https://open.spotify.com/track/0V3wPSX9ygBnCm8...
# 13       200929  https://open.spotify.com/track/59hBR0BCtJsfIbV...
# 14       156943  https://open.spotify.com/track/0NZPBYD5qbEWRs3...
# 15       260253  https://open.spotify.com/track/2LBqCSwhJGcFQeT...
# 16       175238  https://open.spotify.com/track/4uUG5RXrOk84mYE...
# 17       162637  https://open.spotify.com/track/3tt9i3Hhzq84dPS...
# 18       265000  https://open.spotify.com/track/55ZATsjPlTeSTNJ...
# 19       242484  https://open.spotify.com/track/78Sw5GDo6AlGwTw...
# 20       196600  https://open.spotify.com/track/1zsPaEkglFvxjAh...
# 21       176440  https://open.spotify.com/track/1Y3LN4zO1Edc2El...
# 22       163854  https://open.spotify.com/track/7K3BhSpAxZBznis...
# 23       184066  https://open.spotify.com/track/2mpoNBkngUEwnaK...
# 24       174942  https://open.spotify.com/track/1lRtH4FszTrwwlK...
# 25       272373  https://open.spotify.com/track/5mHdCZtVyb4DcJw...
# 26       212253  https://open.spotify.com/track/65FftemJ1DbbZ45...
# 27       208125  https://open.spotify.com/track/0PB0O24JqAuNdOA...
# 28       230453  https://open.spotify.com/track/7MXVkk9YMctZqd1...
# 29       139560  https://open.spotify.com/track/6UN73IYd0hZxLi8...
# 30       198937  https://open.spotify.com/track/2tTmW7RDtMQtBk7...
# 31       244360  https://open.spotify.com/track/7jtQIBanIiJOMS6...
# 32       183956  https://open.spotify.com/track/5XeFesFbtLpXzIV...
# 33       209259  https://open.spotify.com/track/5odlY52u43F5BjB...
# 34       182887  https://open.spotify.com/track/2L9N0zZnd37dwF0...
# 35       148120  https://open.spotify.com/track/4fYte8ZvTK14NEh...
# 36       255693  https://open.spotify.com/track/2mnXxnrX5vCGolN...
# 37       155960  https://open.spotify.com/track/2CeKVsFFXG4QzA4...
# 38       201800  https://open.spotify.com/track/4iZ4pt7kvcaH6Yo...
# 39       128677  https://open.spotify.com/track/7MVIfkyzuUmQ716...
# 40       195373  https://open.spotify.com/track/0JXXNGljqupsJaZ...
# 41       164386  https://open.spotify.com/track/6otePxalBK8AVa2...
# 42       165264  https://open.spotify.com/track/54ipXppHLA8U4yq...
# 43       193463  https://open.spotify.com/track/38UYeBLfvpnDSG9...
# 44       224920  https://open.spotify.com/track/6TBzRwnX2oYd8aO...
# 45       168133  https://open.spotify.com/track/0CYTGMBYkwUxrj1...
# 46       200120  https://open.spotify.com/track/4NoOME4Dhf4xgxb...
# 47       250760  https://open.spotify.com/track/561jH07mF1jHuk7...
# 48       161451  https://open.spotify.com/track/1DxEbt6OSbrkRth...
# 49       123890  https://open.spotify.com/track/4FyesJzVpA39hbY...
#
#     popularity            song_added                album_id  \
# 0           85  2023-03-24T14:50:20Z  0HiZ8fNXwJOQcrf5iflrdz
# 1           96  2023-03-24T14:50:20Z  4kS7bSuU0Jm9LYMosFU2x5
# 2           94  2023-03-24T14:50:20Z  1nrVofqDRs7cpWXJ49qTnP
# 3           96  2023-03-24T14:50:20Z  6cVfHBcp3AdpYY0bBglkLN
# 4           76  2023-03-24T14:50:20Z  35dut3ICqF3NEDkjxfzJJ1
# 5           91  2023-03-24T14:50:20Z  5r36AJ6VOJtp00oxSkBZ5h
# 6           96  2023-03-24T14:50:20Z  1gi2iwr1l8IUyHYHxi01pg
# 7           95  2023-03-24T14:50:20Z  7txGsnDSqVMoRl6RQ9XyZP
# 8           88  2023-03-24T14:50:20Z  5xefnzEqKIWnmTWYFzekGZ
# 9           86  2023-03-24T14:50:20Z  3Mm1P5CEEAiuJqBclr2EyU
# 10          94  2023-03-24T14:50:20Z  2b2GHWESCWEuHiCZ2Skedp
# 11          85  2023-03-24T14:50:20Z  1Uauz6ql2dIPvIOH4JiuhD
# 12          93  2023-03-24T14:50:20Z  151w1FgRZfnKZA9FEcg9Z3
# 13          87  2023-03-24T14:50:20Z  781fDX4OibkZA9fj56Ycbz
# 14          85  2023-03-24T14:50:20Z  3Uq1jNGnD412ZvCb6j2DKV
# 15          89  2023-03-24T14:50:20Z  4AdZV63ycxFLF6Hcol0QnB
# 16          94  2023-03-24T14:50:20Z  7M842DMhYVALrXsw3ty7B3
# 17          72  2023-03-24T14:50:20Z  7ubO2LZJZFpyhiWMZkRwcH
# 18          88  2023-03-24T14:50:20Z  4eoF8b15EaosNzpn2N3Rt9
# 19          93  2023-03-24T14:50:20Z  0OuoHWf8yB0TPzoBWw1R1S
# 20          91  2023-03-24T14:50:20Z  1kjfMVBNhsDeRyAu9zbLfF
# 21          92  2023-03-24T14:50:20Z  7ARtQpvnPN2ucbmVHngLOs
# 22          85  2023-03-24T14:50:20Z  6i7mF7whyRJuLJ4ogbH2wh
# 23          91  2023-03-24T14:50:20Z  2OXBosbXT7Qs3J6vBd6IkI
# 24          91  2023-03-24T14:50:20Z  0s2sLResjP92wRavoj9k0O
# 25          80  2023-03-24T14:50:20Z  3U8n8LzBx2o9gYXvvNq4uH
# 26          92  2023-03-24T14:50:20Z  45ozep8uHHnj5CCittuyXj
# 27          83  2023-03-24T14:50:20Z  6BGN5CVd7koJApotl5Bj8u
# 28          91  2023-03-24T14:50:20Z  2ODvWsOgouMbaA5xf0RkJe
# 29          91  2023-03-24T14:50:20Z  4cAAsw7mPkGt15GXQzWlrM
# 30          92  2023-03-24T14:50:20Z  4PNqWiJAfjj32hVvlchV5u
# 31          61  2023-03-24T14:50:20Z  0KGBW1MQtC2aFPCDUdAkdJ
# 32          91  2023-03-24T14:50:20Z  78bpIziExqiI9qztvNFlQu
# 33          89  2023-03-24T14:50:20Z  69AaAkdktFGnk9POmHENkT
# 34          90  2023-03-24T14:50:20Z  68L5xVV9wydotfDXEik7eD
# 35          50  2023-03-24T14:50:20Z  33inEak0hNKMDePhjGxE61
# 36          86  2023-03-24T14:50:20Z  2AvuFDqTlnxvYhyVaLU6NY
# 37          88  2023-03-24T14:50:20Z  7pijRxgRaBirPz6wDaJIp9
# 38          90  2023-03-24T14:50:20Z  07w0rG5TETcyihsEIZR3qG
# 39          87  2023-03-24T14:50:20Z  26wRfIX4WqKLKHll9O3KnF
# 40          91  2023-03-24T14:50:20Z  493HYe7N5pleudEZRyhE7R
# 41          88  2023-03-24T14:50:20Z  4kS7bSuU0Jm9LYMosFU2x5
# 42          85  2023-03-24T14:50:20Z  6yiXkzHvC0OTmhfDQOEWtS
# 43          89  2023-03-24T14:50:20Z  4wtZQMNTC1O79kDxMBsEan
# 44          89  2023-03-24T14:50:20Z  366AAoKCXunrJSqKqZuafy
# 45          90  2023-03-24T14:50:20Z  31L7J7AO993tSBxAunoeoa
# 46          84  2023-03-24T14:50:20Z  4kS7bSuU0Jm9LYMosFU2x5
# 47          90  2023-03-24T14:50:20Z  1kTlYbs28MXw7hwO0NLYif
# 48          89  2023-03-24T14:50:20Z  5beJZJo0DqVaPVlA1cHwjj
# 49          90  2023-03-24T14:50:20Z  2FD6g8bXEn2uQMYbeqqoCg
#
#                  artist_id
# 0   5YGY8feqx7naU7z4HrwZM6
# 1   790FomKkXshlbRYZFtlgla
# 2   7tYKF4w9nC0nq9CsPZTHyP
# 3   78rUTD7y6Cy67W1RVzYs7t
# 4   1Xyo4u8uXC1ZmMpatF05PJ
# 5   6KImCVD70vtIoJWnq6nGn3
# 6   716NhGYqD1jl2wI1Qkgq36
# 7   0iEtIxbK0KxaSlF7G42ZOp
# 8   0eHQ9o50hj6ZDNBt6Ys1sD
# 9   0XeEobZplHxzM9QzFQWLiR
# 10  46pWGuE3dSwY3bMMXGBvVS
# 11  06HL4z0CvFAxyc27GXpf02
# 12  06HL4z0CvFAxyc27GXpf02
# 13  1oSPZhvZMIrWW5I41kPkkY
# 14  2wY79sveU1sp5g7SokKOiI
# 15  1Xyo4u8uXC1ZmMpatF05PJ
# 16  1Cs0zKBU1kc0i8ypK3B9ai
# 17  0tmwSHipWxN12fsoLcFU3B
# 18  07PdYoE4jVRF6Ut40GgVSP
# 19  5y8tKLUfMvliMe8IKamR32
# 20  1i8SpTcr7yvPOmcqrbnVXY
# 21  5XKFrudbV4IiuE5WuTPRmT
# 22  4oUHIQIBe0LHzYfvXNW4QM
# 23  12GqGscKJx3aE4t07u7eVZ
# 24  0elWFr7TW8piilVRYJUe4P
# 25  5KKpBU5eC2tJDzf0wmlRp2
# 26  6HvZYsbFfjnjFrWF950C9d
# 27  5XJDexmWFLWOkjOEjOVX3e
# 28  1Xyo4u8uXC1ZmMpatF05PJ
# 29  6AMd49uBDJfhf30Ak2QR5s
# 30  716NhGYqD1jl2wI1Qkgq36
# 31  2txHhyCwHjUEpJjWrEyqyX
# 32  7Ln80lUS6He07XvHI8qqHH
# 33  164Uj4eKjl6zTBKfJLFKKK
# 34  1GmsPCcpKgF9OhlNXjOsbS
# 35  5Pwc4xIPtQLFEnJriah9YJ
# 36  4SsVbpTthjScTS7U2hmr1X
# 37  2LRoIwlKmHjgvigdNGBHNo
# 38  7tYKF4w9nC0nq9CsPZTHyP
# 39  5szJHKg5xeUlQ9pTqzdpic
# 40  360IAlyVv4PCEVjgyMZrxK
# 41  790FomKkXshlbRYZFtlgla
# 42  53XhwfbYqKCa1cC15pYq2q
# 43  3AA28KZvwAUcZuOKwyblJQ
# 44  3l9G1G9MxH6DaRhwLklaf5
# 45  2LRoIwlKmHjgvigdNGBHNo
# 46  790FomKkXshlbRYZFtlgla
# 47  7dGJo4pcD2V6oG8kP0tJRR
# 48  0niAkxgT6y57bRbT0Ge94z
# 49  4O15NlyKLIASxsJ0PrXPfz

# %%
song_df.head()
# Out:
#                   song_id                                 song_name  \
# 0  4DHcnVTT87F0zZhRPYmZ3B                                   Flowers
# 1  0DWdj2oZMBFSzRsi2Cvfzf                                       TQG
# 2  1Qrg8KqiBpW07V7PNxwwwL                                 Kill Bill
# 3  6AQbmUe0Qwf5PZnt4HmTXv                        Boy's a liar Pt. 2
# 4  4W4fNrZYkobj539TOWsLO2  Die For You (with Ariana Grande) - Remix
#
#    duration_ms                                                url  popularity  \
# 0       200600  https://open.spotify.com/track/4DHcnVTT87F0zZh...          85
# 1       197933  https://open.spotify.com/track/0DWdj2oZMBFSzRs...          96
# 2       153946  https://open.spotify.com/track/1Qrg8KqiBpW07V7...          94
# 3       131013  https://open.spotify.com/track/6AQbmUe0Qwf5PZn...          96
# 4       232857  https://open.spotify.com/track/4W4fNrZYkobj539...          76
#
#              song_added                album_id               artist_id
# 0  2023-03-24T14:50:20Z  0HiZ8fNXwJOQcrf5iflrdz  5YGY8feqx7naU7z4HrwZM6
# 1  2023-03-24T14:50:20Z  4kS7bSuU0Jm9LYMosFU2x5  790FomKkXshlbRYZFtlgla
# 2  2023-03-24T14:50:20Z  1nrVofqDRs7cpWXJ49qTnP  7tYKF4w9nC0nq9CsPZTHyP
# 3  2023-03-24T14:50:20Z  6cVfHBcp3AdpYY0bBglkLN  78rUTD7y6Cy67W1RVzYs7t
# 4  2023-03-24T14:50:20Z  35dut3ICqF3NEDkjxfzJJ1  1Xyo4u8uXC1ZmMpatF05PJ

# %%
artist_df.head()
# Out:
#                 artist_id     artist_name  \
# 0  5YGY8feqx7naU7z4HrwZM6     Miley Cyrus
# 1  790FomKkXshlbRYZFtlgla         KAROL G
# 2  0EmeFodog0BfCgMzAIvKQp         Shakira
# 3  7tYKF4w9nC0nq9CsPZTHyP             SZA
# 4  78rUTD7y6Cy67W1RVzYs7t  PinkPantheress
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/5YGY8feqx7n...
# 1  https://api.spotify.com/v1/artists/790FomKkXsh...
# 2  https://api.spotify.com/v1/artists/0EmeFodog0B...
# 3  https://api.spotify.com/v1/artists/7tYKF4w9nC0...
# 4  https://api.spotify.com/v1/artists/78rUTD7y6Cy...

# %%
album_df.head()
# Out:
#                  album_id                     name release_date  total_tracks  \
# 0  0HiZ8fNXwJOQcrf5iflrdz  Endless Summer Vacation   2023-03-10            13
# 1  4kS7bSuU0Jm9LYMosFU2x5       MAÑANA SERÁ BONITO   2023-02-24            17
# 2  1nrVofqDRs7cpWXJ49qTnP                      SOS   2022-12-08            23
# 3  6cVfHBcp3AdpYY0bBglkLN       Boy's a liar Pt. 2   2023-02-03             2
# 4  35dut3ICqF3NEDkjxfzJJ1         Starboy (Deluxe)   2023-03-14            21
#
#                                                  url
# 0  https://open.spotify.com/album/0HiZ8fNXwJOQcrf...
# 1  https://open.spotify.com/album/4kS7bSuU0Jm9LYM...
# 2  https://open.spotify.com/album/1nrVofqDRs7cpWX...
# 3  https://open.spotify.com/album/6cVfHBcp3AdpYY0...
# 4  https://open.spotify.com/album/35dut3ICqF3NEDk...

# %%
#convert to datetime for Dtype
album_df['release_date'] = pd.to_datetime(album_df['release_date'])

# %%
song_df['song_added'] = pd.to_datetime(song_df['song_added'])

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      50 non-null     object
#  1   song_name    50 non-null     object
#  2   duration_ms  50 non-null     int64
#  3   url          50 non-null     object
#  4   popularity   50 non-null     int64
#  5   song_added   50 non-null     datetime64[ns, UTC]
#  6   album_id     50 non-null     object
#  7   artist_id    50 non-null     object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 3.2+ KB
